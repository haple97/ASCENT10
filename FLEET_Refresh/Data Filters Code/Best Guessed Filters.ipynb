# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook
# %matplotlib notebook

# %%
# International segment monthly data from all carriers
all_2005 = pd.read_csv('./413215462_T_T100_SEGMENT_ALL_CARRIER.csv')   
columns = ['DEPARTURES_SCHEDULED', 'DEPARTURES_PERFORMED', 'SEATS',
           'PASSENGERS', 'DISTANCE', 'AIR_TIME',
           'UNIQUE_CARRIER', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
           'UNIQUE_CARRIER_ENTITY', 'REGION', 'CARRIER', 'CARRIER_NAME',
           'CARRIER_GROUP', 'CARRIER_GROUP_NEW', 'ORIGIN_AIRPORT_ID',
           'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
           'ORIGIN_CITY_NAME', 'ORIGIN_COUNTRY', 'ORIGIN_COUNTRY_NAME',
           'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
           'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_COUNTRY',
           'DEST_COUNTRY_NAME', 'DEST_WAC', 'AIRCRAFT_GROUP', 'AIRCRAFT_TYPE',
           'AIRCRAFT_CONFIG', 'DISTANCE_GROUP', 'CLASS']


all_2005 = all_2005[columns]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 0                        0.0                  30.0   8946.0      8191.0
# 1                        0.0                   1.0      6.0         1.0
# 2                        0.0                  19.0      0.0         0.0
# 3                        0.0                   6.0     54.0         8.0
# 4                        0.0                  13.0   2236.0      2116.0
# ...                      ...                   ...      ...         ...
# 442105                1467.0                1448.0  13032.0      8116.0
# 442106                1468.0                1464.0  13176.0      8868.0
# 442107                1486.0                1482.0  13338.0      9467.0
# 442108                1554.0                1549.0  13941.0      9273.0
# 442109                2080.0                  26.0    234.0       128.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0         4801.0       0.0             BA       19540
# 1           50.0      31.0             4Y       20324
# 2          347.0    1043.0             KR       20302
# 3           40.0     106.0             8E       20331
# 4         1506.0       0.0             AV       19537
# ...          ...       ...            ...         ...
# 442105      30.0   22589.0             9K       20253
# 442106      30.0   22838.0             9K       20253
# 442107      30.0   23119.0             9K       20253
# 442108      30.0   24164.0             9K       20253
# 442109     172.0       0.0             LW       20300
#
#                UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 0              British Airways Plc                 9493E  ...  SEA
# 1       Yute Air Aka Flight Alaska                 06964  ...  CYF
# 2              Kitty Hawk Aircargo                 06688  ...  PHX
# 3                  Bering Air Inc.                 06992  ...  LUR
# 4        Aerovias Nacl De Colombia                 9327A  ...  BOG
# ...                            ...                   ...  ...  ...
# 442105                    Cape Air                 07021  ...  ACK
# 442106                    Cape Air                 07021  ...  ACK
# 442107                    Cape Air                 07021  ...  HYA
# 442108                    Cape Air                 07021  ...  ACK
# 442109      Pacific Wings Airlines                 07020  ...  HNL
#
#            DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 0             Seattle, WA           US      United States        93
# 1           Chefornak, AK           US      United States         1
# 2             Phoenix, AZ           US      United States        81
# 3       Cape Lisburne, AK           US      United States         1
# 4        Bogota, Colombia           CO           Colombia       327
# ...                   ...          ...                ...       ...
# 442105      Nantucket, MA           US      United States        13
# 442106      Nantucket, MA           US      United States        13
# 442107        Hyannis, MA           US      United States        13
# 442108      Nantucket, MA           US      United States        13
# 442109       Honolulu, HI           US      United States         2
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 0                    8            819                1             10     F
# 1                    0             35                1              1     F
# 2                    7            715                2              1     P
# 3                    4            416                1              1     F
# 4                    6            622                1              4     F
# ...                ...            ...              ...            ...   ...
# 442105               1            125                1              1     F
# 442106               1            125                1              1     F
# 442107               1            125                1              1     F
# 442108               1            125                1              1     F
# 442109               4            416                1              1     F
#
# [442110 rows x 36 columns]

# %%
# 255 WWLMINET network airport list
airport_list = pd.read_excel('./GHG and cost LC stages System Expansion.xlsx', sheet_name='Airport List Map')

# Parse based on the origin and destination
all_2005 = all_2005[all_2005['ORIGIN'].isin(airport_list.Code) & all_2005['DEST'].isin(airport_list.Code)]
all_2005.to_csv ('./prefilter_new_routes.csv') # unfiltered, domestic and trans-Atlantic routes, with monthly demand
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 0                        0.0                  30.0   8946.0      8191.0
# 2                        0.0                  19.0      0.0         0.0
# 4                        0.0                  13.0   2236.0      2116.0
# 5                        0.0                  43.0   8342.0      8016.0
# 6                        0.0                   1.0    148.0        52.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0         4801.0       0.0             BA       19540
# 2          347.0    1043.0             KR       20302
# 4         1506.0       0.0             AV       19537
# 5         1506.0       0.0             AV       19537
# 6         1506.0       0.0             AV       19537
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#               UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 0             British Airways Plc                 9493E  ...  SEA
# 2             Kitty Hawk Aircargo                 06688  ...  PHX
# 4       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 5       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 6       Aerovias Nacl De Colombia                 9327A  ...  BOG
# ...                           ...                   ...  ...  ...
# 442077                Horizon Air                 06580  ...  SEA
# 442078                Horizon Air                 06580  ...  SEA
# 442079                Horizon Air                 06580  ...  PDX
# 442080                Horizon Air                 06580  ...  PDX
# 442081                Horizon Air                 06580  ...  SEA
#
#           DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 0            Seattle, WA           US      United States        93
# 2            Phoenix, AZ           US      United States        81
# 4       Bogota, Colombia           CO           Colombia       327
# 5       Bogota, Colombia           CO           Colombia       327
# 6       Bogota, Colombia           CO           Colombia       327
# ...                  ...          ...                ...       ...
# 442077       Seattle, WA           US      United States        93
# 442078       Seattle, WA           US      United States        93
# 442079      Portland, OR           US      United States        92
# 442080      Portland, OR           US      United States        92
# 442081       Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 0                    8            819                1             10     F
# 2                    7            715                2              1     P
# 4                    6            622                1              4     F
# 5                    6            625                1              4     F
# 6                    6            655                1              4     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [216365 rows x 36 columns]

# %%
# filtered out the all cargo carrier data based on the carrier group id
all_2005 = all_2005[all_2005['CARRIER_GROUP_NEW'] != 7]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 0                        0.0                  30.0   8946.0      8191.0
# 2                        0.0                  19.0      0.0         0.0
# 4                        0.0                  13.0   2236.0      2116.0
# 5                        0.0                  43.0   8342.0      8016.0
# 6                        0.0                   1.0    148.0        52.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0         4801.0       0.0             BA       19540
# 2          347.0    1043.0             KR       20302
# 4         1506.0       0.0             AV       19537
# 5         1506.0       0.0             AV       19537
# 6         1506.0       0.0             AV       19537
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#               UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 0             British Airways Plc                 9493E  ...  SEA
# 2             Kitty Hawk Aircargo                 06688  ...  PHX
# 4       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 5       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 6       Aerovias Nacl De Colombia                 9327A  ...  BOG
# ...                           ...                   ...  ...  ...
# 442077                Horizon Air                 06580  ...  SEA
# 442078                Horizon Air                 06580  ...  SEA
# 442079                Horizon Air                 06580  ...  PDX
# 442080                Horizon Air                 06580  ...  PDX
# 442081                Horizon Air                 06580  ...  SEA
#
#           DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 0            Seattle, WA           US      United States        93
# 2            Phoenix, AZ           US      United States        81
# 4       Bogota, Colombia           CO           Colombia       327
# 5       Bogota, Colombia           CO           Colombia       327
# 6       Bogota, Colombia           CO           Colombia       327
# ...                  ...          ...                ...       ...
# 442077       Seattle, WA           US      United States        93
# 442078       Seattle, WA           US      United States        93
# 442079      Portland, OR           US      United States        92
# 442080      Portland, OR           US      United States        92
# 442081       Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 0                    8            819                1             10     F
# 2                    7            715                2              1     P
# 4                    6            622                1              4     F
# 5                    6            625                1              4     F
# 6                    6            655                1              4     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [216365 rows x 36 columns]

# %%
# filtered out the freight configuration aircraft
all_2005 = all_2005[all_2005['AIRCRAFT_CONFIG'] != 2]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 0                        0.0                  30.0   8946.0      8191.0
# 4                        0.0                  13.0   2236.0      2116.0
# 5                        0.0                  43.0   8342.0      8016.0
# 6                        0.0                   1.0    148.0        52.0
# 9                        0.0                   1.0    120.0       120.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0         4801.0       0.0             BA       19540
# 4         1506.0       0.0             AV       19537
# 5         1506.0       0.0             AV       19537
# 6         1506.0       0.0             AV       19537
# 9          547.0      80.0             DL       19790
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#               UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 0             British Airways Plc                 9493E  ...  SEA
# 4       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 5       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 6       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 9            Delta Air Lines Inc.                 01260  ...  DCA
# ...                           ...                   ...  ...  ...
# 442077                Horizon Air                 06580  ...  SEA
# 442078                Horizon Air                 06580  ...  SEA
# 442079                Horizon Air                 06580  ...  PDX
# 442080                Horizon Air                 06580  ...  PDX
# 442081                Horizon Air                 06580  ...  SEA
#
#           DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 0            Seattle, WA           US      United States        93
# 4       Bogota, Colombia           CO           Colombia       327
# 5       Bogota, Colombia           CO           Colombia       327
# 6       Bogota, Colombia           CO           Colombia       327
# 9         Washington, DC           US      United States        38
# ...                  ...          ...                ...       ...
# 442077       Seattle, WA           US      United States        93
# 442078       Seattle, WA           US      United States        93
# 442079      Portland, OR           US      United States        92
# 442080      Portland, OR           US      United States        92
# 442081       Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 0                    8            819                1             10     F
# 4                    6            622                1              4     F
# 5                    6            625                1              4     F
# 6                    6            655                1              4     F
# 9                    6            619                1              2     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [183983 rows x 36 columns]

# %%
# filtered out seaplane
all_2005 = all_2005[all_2005['AIRCRAFT_CONFIG'] != 4]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 0                        0.0                  30.0   8946.0      8191.0
# 4                        0.0                  13.0   2236.0      2116.0
# 5                        0.0                  43.0   8342.0      8016.0
# 6                        0.0                   1.0    148.0        52.0
# 9                        0.0                   1.0    120.0       120.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0         4801.0       0.0             BA       19540
# 4         1506.0       0.0             AV       19537
# 5         1506.0       0.0             AV       19537
# 6         1506.0       0.0             AV       19537
# 9          547.0      80.0             DL       19790
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#               UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 0             British Airways Plc                 9493E  ...  SEA
# 4       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 5       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 6       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 9            Delta Air Lines Inc.                 01260  ...  DCA
# ...                           ...                   ...  ...  ...
# 442077                Horizon Air                 06580  ...  SEA
# 442078                Horizon Air                 06580  ...  SEA
# 442079                Horizon Air                 06580  ...  PDX
# 442080                Horizon Air                 06580  ...  PDX
# 442081                Horizon Air                 06580  ...  SEA
#
#           DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 0            Seattle, WA           US      United States        93
# 4       Bogota, Colombia           CO           Colombia       327
# 5       Bogota, Colombia           CO           Colombia       327
# 6       Bogota, Colombia           CO           Colombia       327
# 9         Washington, DC           US      United States        38
# ...                  ...          ...                ...       ...
# 442077       Seattle, WA           US      United States        93
# 442078       Seattle, WA           US      United States        93
# 442079      Portland, OR           US      United States        92
# 442080      Portland, OR           US      United States        92
# 442081       Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 0                    8            819                1             10     F
# 4                    6            622                1              4     F
# 5                    6            625                1              4     F
# 6                    6            655                1              4     F
# 9                    6            619                1              2     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [183970 rows x 36 columns]

# %%
# filtered out the all cargo scheduled service, unscheduled passenger service
all_2005 = all_2005[all_2005['CLASS'].isin(['F','A','C','E'])]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 0                        0.0                  30.0   8946.0      8191.0
# 4                        0.0                  13.0   2236.0      2116.0
# 5                        0.0                  43.0   8342.0      8016.0
# 6                        0.0                   1.0    148.0        52.0
# 9                        0.0                   1.0    120.0       120.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 0         4801.0       0.0             BA       19540
# 4         1506.0       0.0             AV       19537
# 5         1506.0       0.0             AV       19537
# 6         1506.0       0.0             AV       19537
# 9          547.0      80.0             DL       19790
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#               UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 0             British Airways Plc                 9493E  ...  SEA
# 4       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 5       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 6       Aerovias Nacl De Colombia                 9327A  ...  BOG
# 9            Delta Air Lines Inc.                 01260  ...  DCA
# ...                           ...                   ...  ...  ...
# 442077                Horizon Air                 06580  ...  SEA
# 442078                Horizon Air                 06580  ...  SEA
# 442079                Horizon Air                 06580  ...  PDX
# 442080                Horizon Air                 06580  ...  PDX
# 442081                Horizon Air                 06580  ...  SEA
#
#           DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 0            Seattle, WA           US      United States        93
# 4       Bogota, Colombia           CO           Colombia       327
# 5       Bogota, Colombia           CO           Colombia       327
# 6       Bogota, Colombia           CO           Colombia       327
# 9         Washington, DC           US      United States        38
# ...                  ...          ...                ...       ...
# 442077       Seattle, WA           US      United States        93
# 442078       Seattle, WA           US      United States        93
# 442079      Portland, OR           US      United States        92
# 442080      Portland, OR           US      United States        92
# 442081       Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 0                    8            819                1             10     F
# 4                    6            622                1              4     F
# 5                    6            625                1              4     F
# 6                    6            655                1              4     F
# 9                    6            619                1              2     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [174037 rows x 36 columns]

# %%
# filtered out routes by international/foreign carriers based on the carrier group id
all_2005 = all_2005[all_2005['CARRIER_GROUP_NEW'] != 0]
all_2005 = all_2005[all_2005['CARRIER_GROUP'] != 0]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 9                        0.0                   1.0    120.0       120.0
# 10                       0.0                   1.0    150.0       128.0
# 13                       0.0                   2.0    248.0       147.0
# 14                       0.0                   2.0    300.0       181.0
# 19                       0.0                   1.0    150.0        99.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 9          547.0      80.0             DL       19790
# 10         732.0     107.0             DL       19790
# 13        1587.0     408.0             HP       19991
# 14         347.0     108.0             HP       19991
# 19         221.0     109.0             DL       19790
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#                UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 9             Delta Air Lines Inc.                 01260  ...  DCA
# 10            Delta Air Lines Inc.                 01260  ...  DFW
# 13      America West Airlines Inc.                 06049  ...  PHX
# 14      America West Airlines Inc.                 06049  ...  PHX
# 19            Delta Air Lines Inc.                 01260  ...  TYS
# ...                            ...                   ...  ...  ...
# 442077                 Horizon Air                 06580  ...  SEA
# 442078                 Horizon Air                 06580  ...  SEA
# 442079                 Horizon Air                 06580  ...  PDX
# 442080                 Horizon Air                 06580  ...  PDX
# 442081                 Horizon Air                 06580  ...  SEA
#
#                DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 9              Washington, DC           US      United States        38
# 10      Dallas/Fort Worth, TX           US      United States        74
# 13                Phoenix, AZ           US      United States        81
# 14                Phoenix, AZ           US      United States        81
# 19              Knoxville, TN           US      United States        54
# ...                       ...          ...                ...       ...
# 442077            Seattle, WA           US      United States        93
# 442078            Seattle, WA           US      United States        93
# 442079           Portland, OR           US      United States        92
# 442080           Portland, OR           US      United States        92
# 442081            Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 9                    6            619                1              2     F
# 10                   6            656                1              2     F
# 13                   6            698                1              4     F
# 14                   6            694                1              1     F
# 19                   6            614                1              1     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [163317 rows x 36 columns]

# %%
all_2005 = all_2005[all_2005['DEPARTURES_SCHEDULED'] > 0]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 183661                   1.0                   1.0    148.0       134.0
# 183662                   1.0                   1.0     50.0        50.0
# 183663                   1.0                   1.0     37.0        34.0
# 183664                   1.0                   1.0     70.0        47.0
# 183665                   1.0                   1.0     50.0        43.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 183661     247.0      42.0             AA       19805
# 183662     299.0      51.0             RP       20418
# 183663     292.0      60.0             RP       20418
# 183664     299.0      49.0             S5       20448
# 183665     292.0      84.0             MQ       20398
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#              UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 183661    American Airlines Inc.                 0A050  ...  DFW
# 183662  Chautauqua Airlines Inc.                 06947  ...  ORD
# 183663  Chautauqua Airlines Inc.                 06947  ...  RIC
# 183664     Shuttle America Corp.                 06911  ...  ORD
# 183665                 Envoy Air                 06820  ...  RIC
# ...                          ...                   ...  ...  ...
# 442077               Horizon Air                 06580  ...  SEA
# 442078               Horizon Air                 06580  ...  SEA
# 442079               Horizon Air                 06580  ...  PDX
# 442080               Horizon Air                 06580  ...  PDX
# 442081               Horizon Air                 06580  ...  SEA
#
#                DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 183661  Dallas/Fort Worth, TX           US      United States        74
# 183662            Chicago, IL           US      United States        41
# 183663           Richmond, VA           US      United States        38
# 183664            Chicago, IL           US      United States        41
# 183665           Richmond, VA           US      United States        38
# ...                       ...          ...                ...       ...
# 442077            Seattle, WA           US      United States        93
# 442078            Seattle, WA           US      United States        93
# 442079           Portland, OR           US      United States        92
# 442080           Portland, OR           US      United States        92
# 442081            Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 183661               6            614                1              1     F
# 183662               6            675                1              1     F
# 183663               6            674                1              1     F
# 183664               6            677                1              1     F
# 183665               6            675                1              1     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [146682 rows x 36 columns]

# %%
all_2005 = all_2005[(all_2005['PASSENGERS'] > 0) & (all_2005['SEATS'] > 0)]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 183661                   1.0                   1.0    148.0       134.0
# 183662                   1.0                   1.0     50.0        50.0
# 183663                   1.0                   1.0     37.0        34.0
# 183664                   1.0                   1.0     70.0        47.0
# 183665                   1.0                   1.0     50.0        43.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 183661     247.0      42.0             AA       19805
# 183662     299.0      51.0             RP       20418
# 183663     292.0      60.0             RP       20418
# 183664     299.0      49.0             S5       20448
# 183665     292.0      84.0             MQ       20398
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#              UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 183661    American Airlines Inc.                 0A050  ...  DFW
# 183662  Chautauqua Airlines Inc.                 06947  ...  ORD
# 183663  Chautauqua Airlines Inc.                 06947  ...  RIC
# 183664     Shuttle America Corp.                 06911  ...  ORD
# 183665                 Envoy Air                 06820  ...  RIC
# ...                          ...                   ...  ...  ...
# 442077               Horizon Air                 06580  ...  SEA
# 442078               Horizon Air                 06580  ...  SEA
# 442079               Horizon Air                 06580  ...  PDX
# 442080               Horizon Air                 06580  ...  PDX
# 442081               Horizon Air                 06580  ...  SEA
#
#                DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 183661  Dallas/Fort Worth, TX           US      United States        74
# 183662            Chicago, IL           US      United States        41
# 183663           Richmond, VA           US      United States        38
# 183664            Chicago, IL           US      United States        41
# 183665           Richmond, VA           US      United States        38
# ...                       ...          ...                ...       ...
# 442077            Seattle, WA           US      United States        93
# 442078            Seattle, WA           US      United States        93
# 442079           Portland, OR           US      United States        92
# 442080           Portland, OR           US      United States        92
# 442081            Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 183661               6            614                1              1     F
# 183662               6            675                1              1     F
# 183663               6            674                1              1     F
# 183664               6            677                1              1     F
# 183665               6            675                1              1     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [146261 rows x 36 columns]

# %%
all_2005 = all_2005[all_2005['DISTANCE'] != 0]
all_2005
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED    SEATS  PASSENGERS  \
# 183661                   1.0                   1.0    148.0       134.0
# 183662                   1.0                   1.0     50.0        50.0
# 183663                   1.0                   1.0     37.0        34.0
# 183664                   1.0                   1.0     70.0        47.0
# 183665                   1.0                   1.0     50.0        43.0
# ...                      ...                   ...      ...         ...
# 442077                 813.0                 788.0  29156.0     21680.0
# 442078                 817.0                 785.0  29045.0     21437.0
# 442079                 818.0                 779.0  28823.0     21968.0
# 442080                 846.0                 816.0  30192.0     24439.0
# 442081                 848.0                 828.0  30636.0     23089.0
#
#         DISTANCE  AIR_TIME UNIQUE_CARRIER  AIRLINE_ID  \
# 183661     247.0      42.0             AA       19805
# 183662     299.0      51.0             RP       20418
# 183663     292.0      60.0             RP       20418
# 183664     299.0      49.0             S5       20448
# 183665     292.0      84.0             MQ       20398
# ...          ...       ...            ...         ...
# 442077     129.0   30227.0             QX       19687
# 442078     129.0   32354.0             QX       19687
# 442079     129.0   29884.0             QX       19687
# 442080     129.0   31195.0             QX       19687
# 442081     129.0   31697.0             QX       19687
#
#              UNIQUE_CARRIER_NAME UNIQUE_CARRIER_ENTITY  ... DEST  \
# 183661    American Airlines Inc.                 0A050  ...  DFW
# 183662  Chautauqua Airlines Inc.                 06947  ...  ORD
# 183663  Chautauqua Airlines Inc.                 06947  ...  RIC
# 183664     Shuttle America Corp.                 06911  ...  ORD
# 183665                 Envoy Air                 06820  ...  RIC
# ...                          ...                   ...  ...  ...
# 442077               Horizon Air                 06580  ...  SEA
# 442078               Horizon Air                 06580  ...  SEA
# 442079               Horizon Air                 06580  ...  PDX
# 442080               Horizon Air                 06580  ...  PDX
# 442081               Horizon Air                 06580  ...  SEA
#
#                DEST_CITY_NAME DEST_COUNTRY  DEST_COUNTRY_NAME  DEST_WAC  \
# 183661  Dallas/Fort Worth, TX           US      United States        74
# 183662            Chicago, IL           US      United States        41
# 183663           Richmond, VA           US      United States        38
# 183664            Chicago, IL           US      United States        41
# 183665           Richmond, VA           US      United States        38
# ...                       ...          ...                ...       ...
# 442077            Seattle, WA           US      United States        93
# 442078            Seattle, WA           US      United States        93
# 442079           Portland, OR           US      United States        92
# 442080           Portland, OR           US      United States        92
# 442081            Seattle, WA           US      United States        93
#
#         AIRCRAFT_GROUP  AIRCRAFT_TYPE  AIRCRAFT_CONFIG DISTANCE_GROUP CLASS
# 183661               6            614                1              1     F
# 183662               6            675                1              1     F
# 183663               6            674                1              1     F
# 183664               6            677                1              1     F
# 183665               6            675                1              1     F
# ...                ...            ...              ...            ...   ...
# 442077               4            483                1              1     F
# 442078               4            483                1              1     F
# 442079               4            483                1              1     F
# 442080               4            483                1              1     F
# 442081               4            483                1              1     F
#
# [146215 rows x 36 columns]

# %%
# Aggregate the data together into the yearly performance by airlines
# Removed UNIQUE_CARRIER and CARRIER to avoid an airline missing those entries
index_column = ['AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
                'UNIQUE_CARRIER_ENTITY', 'REGION','CARRIER_NAME',
                'CARRIER_GROUP', 'CARRIER_GROUP_NEW', 'ORIGIN_AIRPORT_ID',
                'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
                'ORIGIN_CITY_NAME', 'ORIGIN_COUNTRY', 'ORIGIN_COUNTRY_NAME',
                'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
                'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_COUNTRY',
                'DEST_COUNTRY_NAME', 'DEST_WAC']
group_2005 = all_2005.groupby(index_column).agg({'DEPARTURES_SCHEDULED': 'sum', 
                                                 'DEPARTURES_PERFORMED': 'sum',  
                                                 'SEATS': 'sum', 
                                                 'PASSENGERS': 'sum',  
                                                 'DISTANCE': 'mean', 
                                                 'AIR_TIME': 'mean'})

group_2005.reset_index(inplace=True)
group_2005
# Out:
#        AIRLINE_ID                      UNIQUE_CARRIER_NAME  \
# 0           19386                  Northwest Airlines Inc.
# 1           19386                  Northwest Airlines Inc.
# 2           19386                  Northwest Airlines Inc.
# 3           19386                  Northwest Airlines Inc.
# 4           19386                  Northwest Airlines Inc.
# ...           ...                                      ...
# 11428       20500  GoJet Airlines LLC d/b/a United Express
# 11429       20500  GoJet Airlines LLC d/b/a United Express
# 11430       20500  GoJet Airlines LLC d/b/a United Express
# 11431       20502                                   MAXjet
# 11432       20502                                   MAXjet
#
#       UNIQUE_CARRIER_ENTITY REGION                             CARRIER_NAME  \
# 0                     01600      D                  Northwest Airlines Inc.
# 1                     01600      D                  Northwest Airlines Inc.
# 2                     01600      D                  Northwest Airlines Inc.
# 3                     01600      D                  Northwest Airlines Inc.
# 4                     01600      D                  Northwest Airlines Inc.
# ...                     ...    ...                                      ...
# 11428                 07041      D  GoJet Airlines LLC d/b/a United Express
# 11429                 07041      D  GoJet Airlines LLC d/b/a United Express
# 11430                 07041      D  GoJet Airlines LLC d/b/a United Express
# 11431                 17050      A                                   MAXjet
# 11432                 17050      A                                   MAXjet
#
#        CARRIER_GROUP  CARRIER_GROUP_NEW  ORIGIN_AIRPORT_ID  \
# 0                  3                  3              10140
# 1                  3                  3              10257
# 2                  3                  3              10299
# 3                  3                  3              10299
# 4                  3                  3              10397
# ...              ...                ...                ...
# 11428              1                  1              15016
# 11429              1                  1              15096
# 11430              1                  1              15370
# 11431              1                  4              12478
# 11432              1                  4              15018
#
#        ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  ...  \
# 0                    1014001                  30140  ...
# 1                    1025701                  30257  ...
# 2                    1029902                  30299  ...
# 3                    1029902                  30299  ...
# 4                    1039703                  30397  ...
# ...                      ...                    ...  ...
# 11428                1501602                  31123  ...
# 11429                1509601                  35096  ...
# 11430                1537001                  34653  ...
# 11431                1247801                  31703  ...
# 11432                1501802                  30730  ...
#
#                DEST_CITY_NAME DEST_COUNTRY DEST_COUNTRY_NAME DEST_WAC  \
# 0             Minneapolis, MN           US     United States       63
# 1                 Detroit, MI           US     United States       43
# 2                 Detroit, MI           US     United States       43
# 3             Minneapolis, MN           US     United States       63
# 4                 Detroit, MI           US     United States       43
# ...                       ...          ...               ...      ...
# 11428                Reno, NV           US     United States       85
# 11429             Chicago, IL           US     United States       41
# 11430             Chicago, IL           US     United States       41
# 11431  London, United Kingdom           GB    United Kingdom      493
# 11432            New York, NY           US     United States       22
#
#        DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED     SEATS  PASSENGERS  \
# 0                     732.0                 731.0  104372.0     87437.0
# 1                    1341.0                1219.0  137984.0    100038.0
# 2                     103.0                  99.0   18100.0     14790.0
# 3                    1035.0                1028.0  196532.0    157351.0
# 4                    2457.0                2396.0  289656.0    225944.0
# ...                     ...                   ...       ...         ...
# 11428                  10.0                  10.0     660.0        86.0
# 11429                  34.0                  34.0    2244.0      2122.0
# 11430                 156.0                 154.0   10164.0      6149.0
# 11431                  48.0                  43.0    4386.0      1449.0
# 11432                  24.0                  21.0    2142.0       889.0
#
#       DISTANCE      AIR_TIME
# 0        981.0   4505.380952
# 1        488.0   3133.354839
# 2       2986.0   6810.000000
# 3       2518.0  15049.500000
# 4        594.0   3783.789474
# ...        ...           ...
# 11428   1574.0   2164.000000
# 11429    607.0   3231.000000
# 11430    585.0   4268.333333
# 11431   3471.0   9054.500000
# 11432   3471.0  10244.000000
#
# [11433 rows x 29 columns]

# %%
# Add identification A-B route = B-A route
group_2005['ROUTE'] = group_2005.apply(lambda x: x.ORIGIN+'-'+x.DEST if x.ORIGIN > x.DEST 
                                       else x.DEST+'-'+x.ORIGIN, axis=1)
group_2005['DIRROUTE'] = group_2005.apply(lambda x: x.ORIGIN+'-'+x.DEST, axis =1)
group_2005
# Out:
#        AIRLINE_ID                      UNIQUE_CARRIER_NAME  \
# 0           19386                  Northwest Airlines Inc.
# 1           19386                  Northwest Airlines Inc.
# 2           19386                  Northwest Airlines Inc.
# 3           19386                  Northwest Airlines Inc.
# 4           19386                  Northwest Airlines Inc.
# ...           ...                                      ...
# 11428       20500  GoJet Airlines LLC d/b/a United Express
# 11429       20500  GoJet Airlines LLC d/b/a United Express
# 11430       20500  GoJet Airlines LLC d/b/a United Express
# 11431       20502                                   MAXjet
# 11432       20502                                   MAXjet
#
#       UNIQUE_CARRIER_ENTITY REGION                             CARRIER_NAME  \
# 0                     01600      D                  Northwest Airlines Inc.
# 1                     01600      D                  Northwest Airlines Inc.
# 2                     01600      D                  Northwest Airlines Inc.
# 3                     01600      D                  Northwest Airlines Inc.
# 4                     01600      D                  Northwest Airlines Inc.
# ...                     ...    ...                                      ...
# 11428                 07041      D  GoJet Airlines LLC d/b/a United Express
# 11429                 07041      D  GoJet Airlines LLC d/b/a United Express
# 11430                 07041      D  GoJet Airlines LLC d/b/a United Express
# 11431                 17050      A                                   MAXjet
# 11432                 17050      A                                   MAXjet
#
#        CARRIER_GROUP  CARRIER_GROUP_NEW  ORIGIN_AIRPORT_ID  \
# 0                  3                  3              10140
# 1                  3                  3              10257
# 2                  3                  3              10299
# 3                  3                  3              10299
# 4                  3                  3              10397
# ...              ...                ...                ...
# 11428              1                  1              15016
# 11429              1                  1              15096
# 11430              1                  1              15370
# 11431              1                  4              12478
# 11432              1                  4              15018
#
#        ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  ... DEST_COUNTRY_NAME  \
# 0                    1014001                  30140  ...     United States
# 1                    1025701                  30257  ...     United States
# 2                    1029902                  30299  ...     United States
# 3                    1029902                  30299  ...     United States
# 4                    1039703                  30397  ...     United States
# ...                      ...                    ...  ...               ...
# 11428                1501602                  31123  ...     United States
# 11429                1509601                  35096  ...     United States
# 11430                1537001                  34653  ...     United States
# 11431                1247801                  31703  ...    United Kingdom
# 11432                1501802                  30730  ...     United States
#
#       DEST_WAC DEPARTURES_SCHEDULED DEPARTURES_PERFORMED     SEATS  \
# 0           63                732.0                731.0  104372.0
# 1           43               1341.0               1219.0  137984.0
# 2           43                103.0                 99.0   18100.0
# 3           63               1035.0               1028.0  196532.0
# 4           43               2457.0               2396.0  289656.0
# ...        ...                  ...                  ...       ...
# 11428       85                 10.0                 10.0     660.0
# 11429       41                 34.0                 34.0    2244.0
# 11430       41                156.0                154.0   10164.0
# 11431      493                 48.0                 43.0    4386.0
# 11432       22                 24.0                 21.0    2142.0
#
#        PASSENGERS  DISTANCE      AIR_TIME    ROUTE DIRROUTE
# 0         87437.0     981.0   4505.380952  MSP-ABQ  ABQ-MSP
# 1        100038.0     488.0   3133.354839  DTW-ALB  ALB-DTW
# 2         14790.0    2986.0   6810.000000  DTW-ANC  ANC-DTW
# 3        157351.0    2518.0  15049.500000  MSP-ANC  ANC-MSP
# 4        225944.0     594.0   3783.789474  DTW-ATL  ATL-DTW
# ...           ...       ...           ...      ...      ...
# 11428        86.0    1574.0   2164.000000  STL-RNO  STL-RNO
# 11429      2122.0     607.0   3231.000000  SYR-ORD  SYR-ORD
# 11430      6149.0     585.0   4268.333333  TUL-ORD  TUL-ORD
# 11431      1449.0    3471.0   9054.500000  STN-JFK  JFK-STN
# 11432       889.0    3471.0  10244.000000  STN-JFK  STN-JFK
#
# [11433 rows x 31 columns]

# %%
dir_2005 = group_2005.groupby(['DIRROUTE']).agg({'DEPARTURES_SCHEDULED': 'sum', 
                                                                'DEPARTURES_PERFORMED': 'sum', 
                                                                #'PAYLOAD': 'sum', 
                                                                'SEATS': 'sum', 
                                                                'PASSENGERS': 'sum', 
                                                                #'FREIGHT': 'sum', 
                                                                #'MAIL': 'sum', 
                                                                'DISTANCE': 'mean', 
                                                                #'RAMP_TO_RAMP': 'mean', 
                                                                'AIR_TIME': 'mean'})
dir_2005.reset_index(inplace=True)
dir_2005
# Out:
#      DIRROUTE  DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED     SEATS  \
# 0     ABQ-ATL                1396.0                1379.0  226477.0
# 1     ABQ-BWI                 365.0                 364.0   49868.0
# 2     ABQ-CLE                  15.0                  15.0     750.0
# 3     ABQ-COS                 569.0                 553.0   10889.0
# 4     ABQ-CVG                 800.0                 795.0  132522.0
# ...       ...                   ...                   ...       ...
# 4843  ZRH-EWR                 360.0                 359.0   62952.0
# 4844  ZRH-IAD                 366.0                 365.0   70459.0
# 4845  ZRH-JFK                 346.0                 344.0   72959.0
# 4846  ZRH-OKC                   1.0                   1.0     213.0
# 4847  ZRH-ORD                   1.0                   1.0     207.0
#
#       PASSENGERS  DISTANCE      AIR_TIME
# 0       160767.0    1269.0   8524.320000
# 1        43747.0    1670.0   4672.647727
# 2          676.0    1411.0    528.400000
# 3         4994.0     280.0    828.666667
# 4        96517.0    1240.0   7438.500000
# ...          ...       ...           ...
# 4843     50123.0    3946.0  10112.111111
# 4844     53228.0    4158.0   8339.250000
# 4845     58875.0    3931.0  13114.307692
# 4846       206.0    5135.0    646.000000
# 4847        89.0    4443.0    580.000000
#
# [4848 rows x 7 columns]

# %%
# HERE: filtered, directional routes with yearly demand, all airlines combined
dir_2005.to_csv('./best_guessed_2005_yearly.csv')
